# %%
import pandas as pd
import requests

api_key = "9355573a5b2b06939e85cf883267638c"
url = "http://api.weatherstack.com/current"
params = {"access_key": api_key , "query":"Palestine"}
response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print('success!')
else:
    print(f"Error: {response.status_code}")

df = pd.DataFrame(data)
print(df)
# Out:
# success!
#                                   request          location  \
# type                                 City               NaN
# query                 Ramallah, Palestine               NaN
# language                               en               NaN
# unit                                    m               NaN
# name                                  NaN          Ramallah
# country                               NaN         Palestine
# region                                NaN
# lat                                   NaN            31.900
# lon                                   NaN            35.200
# timezone_id                           NaN       Asia/Hebron
# localtime                             NaN  2025-05-19 05:18
# localtime_epoch                       NaN        1747631880
# utc_offset                            NaN               3.0
# observation_time                      NaN               NaN
# temperature                           NaN               NaN
# weather_code                          NaN               NaN
# weather_icons                         NaN               NaN
# weather_descriptions                  NaN               NaN
# astro                                 NaN               NaN
# air_quality                           NaN               NaN
# wind_speed                            NaN               NaN
# wind_degree                           NaN               NaN
# wind_dir                              NaN               NaN
# pressure                              NaN               NaN
# precip                                NaN               NaN
# humidity                              NaN               NaN
# cloudcover                            NaN               NaN
# feelslike                             NaN               NaN
# uv_index                              NaN               NaN
# visibility                            NaN               NaN
# is_day                                NaN               NaN
#
#                                                                 current
# type                                                                NaN
# query                                                               NaN
# language                                                            NaN
# unit                                                                NaN
# name                                                                NaN
# country                                                             NaN
# region                                                              NaN
# lat                                                                 NaN
# lon                                                                 NaN
# timezone_id                                                         NaN
# localtime                                                           NaN
# localtime_epoch                                                     NaN
# utc_offset                                                          NaN
# observation_time                                               02:18 AM
# temperature                                                          20
# weather_code                                                        113
# weather_icons         [https://cdn.worldweatheronline.com/images/wsy...
# weather_descriptions                                           [Clear ]
# astro                 {'sunrise': '05:40 AM', 'sunset': '07:32 PM', ...
# air_quality           {'co': '203.5', 'no2': '11.84', 'o3': '63', 's...
# wind_speed                                                            6
# wind_degree                                                         268
# wind_dir                                                              W
# pressure                                                           1017
# precip                                                                0
# humidity                                                             83
# cloudcover                                                           25
# feelslike                                                            20
# uv_index                                                              0
# visibility                                                           10
# is_day                                                               no
